# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# %matplotlib inline

# %%
#import dataframe
with open('drive/MyDrive/MajorProject/newpickle/amazon/processed_df.pickle', 'rb') as data:
    df = pickle.load(data)
    
# import train features
with open('drive/MyDrive/MajorProject/newpickle/amazon/train_features.pickle', 'rb') as data:
     train_features = pickle.load(data)

# import train labels
with open('drive/MyDrive/MajorProject/newpickle/amazon/train_labels.pickle', 'rb') as data:
     train_labels = pickle.load(data)
        
# import test features
with open('drive/MyDrive/MajorProject/newpickle/amazon/test_features.pickle', 'rb') as data:
     test_features = pickle.load(data)
        
# import test labels
with open('drive/MyDrive/MajorProject/newpickle/amazon/test_labels.pickle', 'rb') as data:
     test_labels = pickle.load(data)
        
# import tfidf
with open('drive/MyDrive/MajorProject/newpickle/amazon/tfidf.pickle', 'rb') as data:
     tfidf = pickle.load(data)

# %%
mnb_classifier = MultinomialNB()

# %%
mnb_classifier.fit(train_features, train_labels)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
mnb_prediction = mnb_classifier.predict(test_features)

# %%
training_accuracy = accuracy_score(train_labels, mnb_classifier.predict(train_features))
print(training_accuracy)
# Out:
# 0.8835568101623148

# %%
testing_accuracy = accuracy_score(test_labels, mnb_prediction)
print(testing_accuracy)
# Out:
# 0.8781749764816557

# %%
print(classification_report(test_labels, mnb_prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.68      0.77       510
#          1.0       0.85      0.96      0.90       952
#          2.0       0.92      0.91      0.92       664
#
#     accuracy                           0.88      2126
#    macro avg       0.89      0.85      0.86      2126
# weighted avg       0.88      0.88      0.87      2126

# %%
conf_matrix = confusion_matrix(test_labels, mnb_prediction)
print(conf_matrix)
# Out:
# [[346 127  37]
#  [ 23 916  13]
#  [ 21  38 605]]

# %%
with open('drive/MyDrive/MajorProject/newpickle/amazon/mnb_classifier.pickle','wb') as data:
    pickle.dump(mnb_classifier, data)
